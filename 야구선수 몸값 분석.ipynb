# %% [markdown]
# # Data Load

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc
# %matplotlib inline
# 한글 폰트 사용을 위해서 세팅
plt.rcParams['font.family'] ='Malgun Gothic'

plt.rcParams['axes.unicode_minus'] =False

plt.rcParams['axes.unicode_minus'] = False

plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_excel("/Users/seheemoon/Desktop/아주대학교/2023-2/빅데이터분석/데분_문세희/Regular_Season_Batter_몸값추가완성.xlsx")
df
# Out:
#       batter_id batter_name  연차  year team   value    avg    G   AB   R  ...  \
# 0             0        가르시아   1  2018   LG     NaN  0.339   50  183  27  ...
# 1             1         강경학   1  2011   한화  2400.0  0.000    2    1   0  ...
# 2             1         강경학   2  2014   한화  6500.0  0.221   41   86  11  ...
# 3             1         강경학   3  2015   한화  6500.0  0.257  120  311  50  ...
# 4             1         강경학   4  2016   한화  6200.0  0.158   46  101  16  ...
# ...         ...         ...  ..   ...  ...     ...    ...  ...  ...  ..  ...
# 2449        344         황진수   3  2014   롯데  2800.0  0.000    5    5   0  ...
# 2450        344         황진수   4  2015   롯데  2800.0  0.000    2    2   0  ...
# 2451        344         황진수   5  2016   롯데  2800.0  0.000   11   10   2  ...
# 2452        344         황진수   6  2017   롯데  6200.0  0.291   60  117  18  ...
# 2453        344         황진수   7  2018   롯데  4000.0  0.167   18   24   6  ...
#
#       GDP    SLG    OBP   E  height/weight      year_born   position  \
# 0       3  0.519  0.383   9     177cm/93kg  1985년 04월 12일  내야수(우투우타)
# 1       0  0.000  0.000   1     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
# 2       1  0.349  0.337   6     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
# 3       3  0.325  0.348  15     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
# 4       5  0.257  0.232   7     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
# ...   ...    ...    ...  ..            ...            ...        ...
# 2449    0  0.000  0.000   0     181cm/82kg  1989년 02월 15일  내야수(우투양타)
# 2450    0  0.000  0.000   0     181cm/82kg  1989년 02월 15일  내야수(우투양타)
# 2451    0  0.000  0.000   0     181cm/82kg  1989년 02월 15일  내야수(우투양타)
# 2452    2  0.402  0.359   4     181cm/82kg  1989년 02월 15일  내야수(우투양타)
# 2453    0  0.333  0.231   3     181cm/82kg  1989년 02월 15일  내야수(우투양타)
#
#                                       career  starting_salary    OPS
# 0     쿠바 Ciego de Avila Maximo Gomez Baez(대)              NaN  0.902
# 1                          광주대성초-광주동성중-광주동성고          10000만원  0.000
# 2                          광주대성초-광주동성중-광주동성고          10000만원  0.686
# 3                          광주대성초-광주동성중-광주동성고          10000만원  0.673
# 4                          광주대성초-광주동성중-광주동성고          10000만원  0.489
# ...                                      ...              ...    ...
# 2449                             석천초-대헌중-공주고           4000만원  0.000
# 2450                             석천초-대헌중-공주고           4000만원  0.000
# 2451                             석천초-대헌중-공주고           4000만원  0.000
# 2452                             석천초-대헌중-공주고           4000만원  0.761
# 2453                             석천초-대헌중-공주고           4000만원  0.564
#
# [2454 rows x 31 columns]

# %% [markdown]
# # Data Preprocessing

# %%
df.isnull().sum()
# Out:
# batter_id             0
# batter_name           0
# 연차                    0
# year                  0
# team                  0
# value               221
# avg                  26
# G                     0
# AB                    0
# R                     0
# H                     0
# 2B                    0
# 3B                    0
# HR                    0
# TB                    0
# RBI                   0
# SB                    0
# CS                    0
# BB                    0
# HBP                   0
# SO                    0
# GDP                   0
# SLG                  26
# OBP                  24
# E                     0
# height/weight       802
# year_born             0
# position            802
# career                0
# starting_salary    1067
# OPS                  26
# dtype: int64

# %%
drop_lst = ['batter_id', 'height/weight', 'year_born', 'position', 'career', 'starting_salary']
for x in drop_lst:
    df.drop(x, axis=1, inplace=True)
df
# Out:
#      batter_name  연차  year team   value    avg    G   AB   R   H  ...  SB  CS  \
# 0           가르시아   1  2018   LG     NaN  0.339   50  183  27  62  ...   5   0
# 1            강경학   1  2011   한화  2400.0  0.000    2    1   0   0  ...   0   0
# 2            강경학   2  2014   한화  6500.0  0.221   41   86  11  19  ...   0   0
# 3            강경학   3  2015   한화  6500.0  0.257  120  311  50  80  ...   4   3
# 4            강경학   4  2016   한화  6200.0  0.158   46  101  16  16  ...   0   0
# ...          ...  ..   ...  ...     ...    ...  ...  ...  ..  ..  ...  ..  ..
# 2449         황진수   3  2014   롯데  2800.0  0.000    5    5   0   0  ...   0   0
# 2450         황진수   4  2015   롯데  2800.0  0.000    2    2   0   0  ...   0   0
# 2451         황진수   5  2016   롯데  2800.0  0.000   11   10   2   0  ...   0   1
# 2452         황진수   6  2017   롯데  6200.0  0.291   60  117  18  34  ...   4   0
# 2453         황진수   7  2018   롯데  4000.0  0.167   18   24   6   4  ...   1   0
#
#       BB  HBP  SO  GDP    SLG    OBP   E    OPS
# 0      9    8  25    3  0.519  0.383   9  0.902
# 1      0    0   1    0  0.000  0.000   1  0.000
# 2     13    2  28    1  0.349  0.337   6  0.686
# 3     40    5  58    3  0.325  0.348  15  0.673
# 4      8    2  30    5  0.257  0.232   7  0.489
# ...   ..  ...  ..  ...    ...    ...  ..    ...
# 2449   0    0   1    0  0.000  0.000   0  0.000
# 2450   0    0   0    0  0.000  0.000   0  0.000
# 2451   0    0   5    0  0.000  0.000   0  0.000
# 2452  10    3  38    2  0.402  0.359   4  0.761
# 2453   2    0   5    0  0.333  0.231   3  0.564
#
# [2454 rows x 25 columns]

# %%
df.dropna(axis=0, inplace=True)
df
# Out:
#      batter_name  연차  year team   value    avg    G   AB   R   H  ...  SB  CS  \
# 1            강경학   1  2011   한화  2400.0  0.000    2    1   0   0  ...   0   0
# 2            강경학   2  2014   한화  6500.0  0.221   41   86  11  19  ...   0   0
# 3            강경학   3  2015   한화  6500.0  0.257  120  311  50  80  ...   4   3
# 4            강경학   4  2016   한화  6200.0  0.158   46  101  16  16  ...   0   0
# 5            강경학   5  2017   한화  5800.0  0.214   59   84  17  18  ...   1   1
# ...          ...  ..   ...  ...     ...    ...  ...  ...  ..  ..  ...  ..  ..
# 2449         황진수   3  2014   롯데  2800.0  0.000    5    5   0   0  ...   0   0
# 2450         황진수   4  2015   롯데  2800.0  0.000    2    2   0   0  ...   0   0
# 2451         황진수   5  2016   롯데  2800.0  0.000   11   10   2   0  ...   0   1
# 2452         황진수   6  2017   롯데  6200.0  0.291   60  117  18  34  ...   4   0
# 2453         황진수   7  2018   롯데  4000.0  0.167   18   24   6   4  ...   1   0
#
#       BB  HBP  SO  GDP    SLG    OBP   E    OPS
# 1      0    0   1    0  0.000  0.000   1  0.000
# 2     13    2  28    1  0.349  0.337   6  0.686
# 3     40    5  58    3  0.325  0.348  15  0.673
# 4      8    2  30    5  0.257  0.232   7  0.489
# 5      8    1  19    1  0.262  0.290   4  0.552
# ...   ..  ...  ..  ...    ...    ...  ..    ...
# 2449   0    0   1    0  0.000  0.000   0  0.000
# 2450   0    0   0    0  0.000  0.000   0  0.000
# 2451   0    0   5    0  0.000  0.000   0  0.000
# 2452  10    3  38    2  0.402  0.359   4  0.761
# 2453   2    0   5    0  0.333  0.231   3  0.564
#
# [2213 rows x 25 columns]

# %%
df.columns = ['이름', '연차', '연도', '팀명', '몸값(만원)', '타율', '경기수', '타수', '득점', '안타', '2루타', '3루타', '홈런',
              '루타', '타점', '도루', '도루실패', '볼넷', '데드볼', '삼진', '병살타', '장타율', '출루율', '실책', 'OPS']
df
# Out:
#        이름  연차    연도  팀명  몸값(만원)     타율  경기수   타수  득점  안타  ...  도루  도루실패  볼넷  \
# 1     강경학   1  2011  한화  2400.0  0.000    2    1   0   0  ...   0     0   0
# 2     강경학   2  2014  한화  6500.0  0.221   41   86  11  19  ...   0     0  13
# 3     강경학   3  2015  한화  6500.0  0.257  120  311  50  80  ...   4     3  40
# 4     강경학   4  2016  한화  6200.0  0.158   46  101  16  16  ...   0     0   8
# 5     강경학   5  2017  한화  5800.0  0.214   59   84  17  18  ...   1     1   8
# ...   ...  ..   ...  ..     ...    ...  ...  ...  ..  ..  ...  ..   ...  ..
# 2449  황진수   3  2014  롯데  2800.0  0.000    5    5   0   0  ...   0     0   0
# 2450  황진수   4  2015  롯데  2800.0  0.000    2    2   0   0  ...   0     0   0
# 2451  황진수   5  2016  롯데  2800.0  0.000   11   10   2   0  ...   0     1   0
# 2452  황진수   6  2017  롯데  6200.0  0.291   60  117  18  34  ...   4     0  10
# 2453  황진수   7  2018  롯데  4000.0  0.167   18   24   6   4  ...   1     0   2
#
#       데드볼  삼진  병살타    장타율    출루율  실책    OPS
# 1       0   1    0  0.000  0.000   1  0.000
# 2       2  28    1  0.349  0.337   6  0.686
# 3       5  58    3  0.325  0.348  15  0.673
# 4       2  30    5  0.257  0.232   7  0.489
# 5       1  19    1  0.262  0.290   4  0.552
# ...   ...  ..  ...    ...    ...  ..    ...
# 2449    0   1    0  0.000  0.000   0  0.000
# 2450    0   0    0  0.000  0.000   0  0.000
# 2451    0   5    0  0.000  0.000   0  0.000
# 2452    3  38    2  0.402  0.359   4  0.761
# 2453    0   5    0  0.333  0.231   3  0.564
#
# [2213 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2213 entries, 1 to 2453
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      2213 non-null   object
#  1   연차      2213 non-null   int64
#  2   연도      2213 non-null   int64
#  3   팀명      2213 non-null   object
#  4   몸값(만원)  2213 non-null   float64
#  5   타율      2213 non-null   float64
#  6   경기수     2213 non-null   int64
#  7   타수      2213 non-null   int64
#  8   득점      2213 non-null   int64
#  9   안타      2213 non-null   int64
#  10  2루타     2213 non-null   int64
#  11  3루타     2213 non-null   int64
#  12  홈런      2213 non-null   int64
#  13  루타      2213 non-null   int64
#  14  타점      2213 non-null   int64
#  15  도루      2213 non-null   int64
#  16  도루실패    2213 non-null   int64
#  17  볼넷      2213 non-null   int64
#  18  데드볼     2213 non-null   int64
#  19  삼진      2213 non-null   int64
#  20  병살타     2213 non-null   int64
#  21  장타율     2213 non-null   float64
#  22  출루율     2213 non-null   float64
#  23  실책      2213 non-null   int64
#  24  OPS     2213 non-null   float64
# dtypes: float64(5), int64(18), object(2)
# memory usage: 449.5+ KB

# %%
# Year 열 값이 2018이거나 2015인 데이터만 모으기
years_to_select = [2015, 2016]
df_1516 = df[df['연도'].isin(years_to_select)]

# 모인 데이터 출력
df_1516
# Out:
#        이름  연차    연도  팀명    몸값(만원)     타율  경기수   타수  득점   안타  ...  도루  도루실패  \
# 3     강경학   3  2015  한화    6500.0  0.257  120  311  50   80  ...   4     3
# 4     강경학   4  2016  한화    6200.0  0.158   46  101  16   16  ...   0     0
# 8     강구성   2  2015  NC    2700.0  0.200    4    5   0    1  ...   0     0
# 9     강구성   3  2016  NC    2700.0  0.000    2    3   0    0  ...   0     0
# 39    강민국   2  2015  NC    2700.0  0.000    1    2   0    0  ...   0     0
# ...   ...  ..   ...  ..       ...    ...  ...  ...  ..  ...  ...  ..   ...
# 2431  황윤호   2  2016  NC    3000.0  0.083   33   12   7    1  ...   1     0
# 2442  황재균   9  2015  롯데   50000.0  0.290  144  534  95  155  ...  11    10
# 2443  황재균  10  2016  롯데  120000.0  0.335  127  498  97  167  ...  25    10
# 2450  황진수   4  2015  롯데    2800.0  0.000    2    2   0    0  ...   0     0
# 2451  황진수   5  2016  롯데    2800.0  0.000   11   10   2    0  ...   0     1
#
#       볼넷  데드볼   삼진  병살타    장타율    출루율  실책    OPS
# 3     40    5   58    3  0.325  0.348  15  0.673
# 4      8    2   30    5  0.257  0.232   7  0.489
# 8      0    0    0    0  0.400  0.200   0  0.600
# 9      0    0    1    0  0.000  0.000   0  0.000
# 39     0    0    1    0  0.000  0.000   0  0.000
# ...   ..  ...  ...  ...    ...    ...  ..    ...
# 2431   0    0    5    0  0.083  0.083   0  0.166
# 2442  48    4  122   14  0.521  0.350  16  0.871
# 2443  49    4   66   10  0.570  0.394  15  0.964
# 2450   0    0    0    0  0.000  0.000   0  0.000
# 2451   0    0    5    0  0.000  0.000   0  0.000
#
# [368 rows x 25 columns]

# %%
from sklearn.preprocessing import StandardScaler
numeric_feature3 = df_1516.columns[(df.dtypes=='int64') | (df.dtypes=='float')]
num_data3 = df_1516[numeric_feature3]
# StandardScaler 객체 생성
scaler = StandardScaler()

# 스케일링할 열 선택
columns_to_scale_1516 = num_data3.columns  # 모든 열에 대해 스케일링을 수행하려면 이 부분을 수정해야 할 수 있습니다.

# 선택한 열을 기반으로 스케일링 수행
scaled_data_1516 = scaler.fit_transform(df_1516[columns_to_scale_1516])

# 스케일링된 데이터를 새로운 데이터프레임으로 생성
scaled_df_1516 = pd.DataFrame(scaled_data_1516, columns=columns_to_scale_1516)

scaled_df_1516
# Out:
#            연차        연도    몸값(만원)        타율       경기수        타수        득점  \
# 0   -0.808955 -1.038795 -0.494639  0.033471  0.908201  0.536658  0.491787
# 1   -0.583428  0.962653 -0.505758 -0.931249 -0.666994 -0.628083 -0.558432
# 2   -1.034482 -1.038795 -0.635481 -0.521974 -1.561023 -1.160536 -1.052653
# 3   -0.808955  0.962653 -0.635481 -2.470903 -1.603596 -1.171628 -1.052653
# 4   -1.034482 -1.038795 -0.635481 -2.470903 -1.624883 -1.177175 -1.052653
# ..        ...       ...       ...       ...       ...       ...       ...
# 363 -1.034482  0.962653 -0.624362 -1.662098 -0.943717 -1.121711 -0.836432
# 364  0.544206 -1.038795  1.117632  0.355044  1.419075  1.773502  1.881782
# 365  0.769733  0.962653  3.712090  0.793553  1.057206  1.573832  1.943560
# 366 -0.583428 -1.038795 -0.631775 -2.470903 -1.603596 -1.177175 -1.052653
# 367 -0.357901  0.962653 -0.631775 -2.470903 -1.412018 -1.132804 -0.990876
#
#            안타       2루타       3루타  ...        도루      도루실패        볼넷  \
# 0    0.312905 -0.349882  1.663827  ... -0.117276  0.207039  0.709652
# 1   -0.799982 -0.719341  0.543446  ... -0.583846 -0.729728 -0.635625
# 2   -1.060815 -0.904071 -0.576935  ... -0.583846 -0.729728 -0.971945
# 3   -1.078204 -0.996436 -0.576935  ... -0.583846 -0.729728 -0.971945
# 4   -1.078204 -0.996436 -0.576935  ... -0.583846 -0.729728 -0.971945
# ..        ...       ...       ...  ...       ...       ...       ...
# 363 -1.060815 -0.996436 -0.576935  ... -0.467203 -0.729728 -0.971945
# 364  1.617070  2.790522  0.543446  ...  0.699220  2.392829  1.045972
# 365  1.825736  1.405050  2.224017  ...  2.332214  2.392829  1.088011
# 366 -1.078204 -0.996436 -0.576935  ... -0.583846 -0.729728 -0.971945
# 367 -1.078204 -0.996436 -0.576935  ... -0.583846 -0.417472 -0.971945
#
#           데드볼        삼진       병살타       장타율       출루율        실책       OPS
# 0    0.301672  0.450159 -0.389027 -0.258324  0.226005  2.380966 -0.066948
# 1   -0.390732 -0.362746  0.010867 -0.677054 -0.838712  0.672982 -0.777859
# 2   -0.852334 -1.233717 -0.988866  0.203510 -1.132427 -0.821503 -0.348995
# 3   -0.852334 -1.204684 -0.988866 -2.259607 -2.968145 -0.821503 -2.667183
# 4   -0.852334 -1.204684 -0.988866 -2.259607 -2.968145 -0.821503 -2.667183
# ..        ...       ...       ...       ...       ...       ...       ...
# 363 -0.852334 -1.088555 -0.988866 -1.748510 -2.206322 -0.821503 -2.025817
# 364  0.070871  2.308229  1.810386  0.948603  0.244362  2.594463  0.698054
# 365  0.070871  0.682418  1.010600  1.250335  0.648220  2.380966  1.057373
# 366 -0.852334 -1.233717 -0.988866 -2.259607 -2.968145 -0.821503 -2.667183
# 367 -0.852334 -1.088555 -0.988866 -2.259607 -2.968145 -0.821503 -2.667183
#
# [368 rows x 23 columns]

# %% [markdown]
# # 상관분석

# %%
corr_1516 = scaled_df_1516.corr()
plt.figure(figsize= (20,12))
sns.heatmap(corr_1516, fmt='.2f', annot=True)
plt.show()
# Out:
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 47800 (\N{HANGUL SYLLABLE MOM}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 46301 (\N{HANGUL SYLLABLE DEUG}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 51216 (\N{HANGUL SYLLABLE JEOM}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 50504 (\N{HANGUL SYLLABLE AN}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 54856 (\N{HANGUL SYLLABLE HOM}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 47088 (\N{HANGUL SYLLABLE REON}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 54056 (\N{HANGUL SYLLABLE PAE}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 48380 (\N{HANGUL SYLLABLE BOL}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 45367 (\N{HANGUL SYLLABLE NES}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 45936 (\N{HANGUL SYLLABLE DE}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 49340 (\N{HANGUL SYLLABLE SAM}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 48337 (\N{HANGUL SYLLABLE BYEONG}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 49332 (\N{HANGUL SYLLABLE SAL}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:95: UserWarning: Glyph 52293 (\N{HANGUL SYLLABLE CAEG}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 47800 (\N{HANGUL SYLLABLE MOM}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 46301 (\N{HANGUL SYLLABLE DEUG}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 51216 (\N{HANGUL SYLLABLE JEOM}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 50504 (\N{HANGUL SYLLABLE AN}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 54856 (\N{HANGUL SYLLABLE HOM}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 47088 (\N{HANGUL SYLLABLE REON}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 54056 (\N{HANGUL SYLLABLE PAE}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 48380 (\N{HANGUL SYLLABLE BOL}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 45367 (\N{HANGUL SYLLABLE NES}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 45936 (\N{HANGUL SYLLABLE DE}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 49340 (\N{HANGUL SYLLABLE SAM}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 48337 (\N{HANGUL SYLLABLE BYEONG}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 49332 (\N{HANGUL SYLLABLE SAL}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:660: UserWarning: Glyph 52293 (\N{HANGUL SYLLABLE CAEG}) missing from current font.
#   bboxes = [l.get_window_extent() for l in labels]
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47800 (\N{HANGUL SYLLABLE MOM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46301 (\N{HANGUL SYLLABLE DEUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51216 (\N{HANGUL SYLLABLE JEOM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50504 (\N{HANGUL SYLLABLE AN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54856 (\N{HANGUL SYLLABLE HOM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47088 (\N{HANGUL SYLLABLE REON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54056 (\N{HANGUL SYLLABLE PAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48380 (\N{HANGUL SYLLABLE BOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45367 (\N{HANGUL SYLLABLE NES}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45936 (\N{HANGUL SYLLABLE DE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49340 (\N{HANGUL SYLLABLE SAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48337 (\N{HANGUL SYLLABLE BYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49332 (\N{HANGUL SYLLABLE SAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52293 (\N{HANGUL SYLLABLE CAEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # OLS 다중회귀분석

# %%
import statsmodels.api as sm
# numeric_feature4 = scaled_df_1516.columns[(df.dtypes=='int64') | (df.dtypes=='float')]
# num_data4 = scaled_df_1516[numeric_feature4]
# crim, rm, lstat을 통한 다중 선형회귀분석
x_data = scaled_df_1516[['연차', '연도', '타율', '경기수', '타수', '득점', '안타', '2루타', '3루타', '홈런',
       '루타', '타점', '도루', '도루실패', '볼넷', '데드볼', '삼진', '병살타', '장타율', '출루율', '실책',
       'OPS']] #변수 여러개
target2 = scaled_df_1516[["몸값(만원)"]]

# for b0, 상수항 추가
x_data1 = sm.add_constant(x_data, has_constant = "add")

# OLS 검정
multi_model = sm.OLS(target2, x_data1)
fitted_multi_model = multi_model.fit()
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 몸값(만원)   R-squared:                       0.737
# Model:                            OLS   Adj. R-squared:                  0.722
# Method:                 Least Squares   F-statistic:                     48.74
# Date:                Fri, 25 Aug 2023   Prob (F-statistic):           5.65e-88
# Time:                        15:08:19   Log-Likelihood:                -276.09
# No. Observations:                 368   AIC:                             594.2
# Df Residuals:                     347   BIC:                             676.3
# Df Model:                          20
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.457e-16      0.028    5.3e-15      1.000      -0.054       0.054
# 연차             0.2663      0.034      7.784      0.000       0.199       0.334
# 연도            -0.0004      0.029     -0.014      0.989      -0.057       0.056
# 타율             0.1315      0.101      1.302      0.194      -0.067       0.330
# 경기수           -0.0059      0.082     -0.071      0.943      -0.168       0.156
# 타수            -0.9900      0.322     -3.070      0.002      -1.624      -0.356
# 득점            -0.1316      0.154     -0.853      0.394      -0.435       0.172
# 안타             0.5147      0.229      2.252      0.025       0.065       0.964
# 2루타            0.0512      0.094      0.546      0.585      -0.133       0.236
# 3루타           -0.1359      0.045     -3.004      0.003      -0.225      -0.047
# 홈런             0.1157      0.093      1.248      0.213      -0.067       0.298
# 루타             0.3599      0.135      2.670      0.008       0.095       0.625
# 타점             0.4608      0.155      2.970      0.003       0.156       0.766
# 도루             0.2025      0.057      3.524      0.000       0.090       0.316
# 도루실패          -0.0282      0.051     -0.548      0.584      -0.129       0.073
# 볼넷             0.4836      0.077      6.272      0.000       0.332       0.635
# 데드볼            0.1366      0.040      3.378      0.001       0.057       0.216
# 삼진            -0.2368      0.080     -2.950      0.003      -0.395      -0.079
# 병살타           -0.0692      0.058     -1.195      0.233      -0.183       0.045
# 장타율           -0.0364      0.052     -0.703      0.483      -0.138       0.065
# 출루율           -0.0970      0.083     -1.163      0.246      -0.261       0.067
# 실책             0.0180      0.038      0.477      0.633      -0.056       0.092
# OPS           -0.0636      0.036     -1.789      0.074      -0.134       0.006
# ==============================================================================
# Omnibus:                       73.455   Durbin-Watson:                   1.601
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              319.042
# Skew:                           0.777   Prob(JB):                     5.26e-70
# Kurtosis:                       7.289   Cond. No.                     2.98e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.24e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# import statsmodels.api as sm
# numeric_feature4 = scaled_df_1516.columns[(df.dtypes=='int64') | (df.dtypes=='float')]
# num_data4 = scaled_df_1516[numeric_feature4]
# crim, rm, lstat을 통한 다중 선형회귀분석
x_data = scaled_df_1516[['연차', '타율', '타수', '득점', '2루타', '3루타', '홈런',
       '루타', '타점', '도루', '볼넷', '데드볼', '삼진', '병살타',
       'OPS']] #변수 여러개
target2 = scaled_df_1516[["몸값(만원)"]]

# for b0, 상수항 추가
x_data1 = sm.add_constant(x_data, has_constant = "add")

# OLS 검정
multi_model = sm.OLS(target2, x_data1)
fitted_multi_model = multi_model.fit()
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 몸값(만원)   R-squared:                       0.737
# Model:                            OLS   Adj. R-squared:                  0.725
# Method:                 Least Squares   F-statistic:                     65.64
# Date:                Fri, 25 Aug 2023   Prob (F-statistic):           3.49e-92
# Time:                        15:08:19   Log-Likelihood:                -276.67
# No. Observations:                 368   AIC:                             585.3
# Df Residuals:                     352   BIC:                             647.9
# Df Model:                          15
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.214e-17      0.027   4.44e-16      1.000      -0.054       0.054
# 연차             0.2633      0.034      7.806      0.000       0.197       0.330
# 타율             0.0974      0.084      1.155      0.249      -0.068       0.263
# 타수            -0.9635      0.263     -3.659      0.000      -1.481      -0.446
# 득점            -0.1421      0.151     -0.940      0.348      -0.439       0.155
# 2루타           -0.0263      0.111     -0.237      0.813      -0.244       0.191
# 3루타           -0.1661      0.047     -3.506      0.001      -0.259      -0.073
# 홈런            -0.0883      0.149     -0.592      0.554      -0.382       0.205
# 루타             1.1283      0.445      2.534      0.012       0.253       2.004
# 타점             0.4658      0.150      3.098      0.002       0.170       0.761
# 도루             0.1898      0.052      3.648      0.000       0.087       0.292
# 볼넷             0.4623      0.070      6.587      0.000       0.324       0.600
# 데드볼            0.1332      0.039      3.400      0.001       0.056       0.210
# 삼진            -0.2411      0.078     -3.073      0.002      -0.395      -0.087
# 병살타           -0.0660      0.057     -1.150      0.251      -0.179       0.047
# OPS           -0.1591      0.092     -1.725      0.085      -0.340       0.022
# ==============================================================================
# Omnibus:                       72.724   Durbin-Watson:                   1.596
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              310.981
# Skew:                           0.773   Prob(JB):                     2.96e-68
# Kurtosis:                       7.230   Cond. No.                         58.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Principal component analysis

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
# VIF 계산을 위해 상수항 열 추가
cut_1516 = scaled_df_1516[['연차', '타율', '타수', '득점', '2루타', '3루타', '홈런',
       '루타', '타점', '도루', '볼넷', '데드볼', '삼진', '병살타',
       'OPS']]
df_with_const = add_constant(cut_1516)

# VIF 계산
vif_data = pd.DataFrame()
vif_data["Variable"] = df_with_const.columns
vif_data["VIF"] = [variance_inflation_factor(df_with_const.values, i) for i in range(df_with_const.shape[1])]

# VIF 값 출력
vif_data
# Out:
#    Variable         VIF
# 0     const    1.000000
# 1        연차    1.520649
# 2        타율    9.499244
# 3        타수   92.662884
# 4        득점   30.538633
# 5       2루타   16.360041
# 6       3루타    2.998820
# 7        홈런   29.722540
# 8        루타  265.022122
# 9        타점   30.206550
# 10       도루    3.616788
# 11       볼넷    6.584215
# 12      데드볼    2.050385
# 13       삼진    8.223879
# 14      병살타    4.402582
# 15      OPS   11.364733

# %%
# scree plot

# 데이터의 평균 계산
mean = np.mean(scaled_df_1516, axis=0)

# 공분산 행렬 계산
cov_matrix = np.cov(scaled_df_1516, rowvar=False)

# 공분산 행렬의 고유값과 고유벡터 계산
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

# Scree plot 그리기
explained_variance_ratio = eigenvalues / np.sum(eigenvalues)
plt.figure(figsize=(60, 10))
plt.plot(np.arange(1, len(explained_variance_ratio) + 1), explained_variance_ratio, marker='o')
plt.title("Scree Plot")
plt.xlabel("주성분 번호")
plt.ylabel("설명된 분산 비율")
plt.xticks(np.arange(1, len(explained_variance_ratio) + 1))
plt.show()
# Out:
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48264 (\N{HANGUL SYLLABLE BEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54840 (\N{HANGUL SYLLABLE HO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46108 (\N{HANGUL SYLLABLE DOEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
# PCA를 위한 데이터 전처리
numeric_feature = df_1516.columns[(df.dtypes=='int64') | (df.dtypes=='float')]
num_data = df_1516[numeric_feature]
scaler = StandardScaler()
scaled_data = scaler.fit_transform(num_data)

# PCA 모델 초기화
n_components = 2  # 원하는 차원 수
pca = PCA(n_components=n_components)

# PCA 모델 훈련 및 데이터 변환
pca_result = pca.fit_transform(scaled_data)

# 결과 데이터프레임 생성
pca_df = pd.DataFrame(data=pca_result, columns=[f'PC{i+1}' for i in range(n_components)])

# %%
# 주성분(PC) 로딩 출력
loading_matrix = pca.components_
loading_df = pd.DataFrame(loading_matrix, columns=scaled_df_1516.columns)

print("Loading Matrix (PCs as columns):")
loading_df
# Out:
# Loading Matrix (PCs as columns):
#          연차        연도    몸값(만원)        타율       경기수        타수        득점  \
# 0  0.127127  0.003497  0.197767  0.151126  0.244509  0.265511  0.263095
# 1  0.045898  0.093452  0.010652  0.462449 -0.111690 -0.115592 -0.107595
#
#          안타       2루타       3루타  ...        도루      도루실패       볼넷       데드볼  \
# 0  0.266694  0.257102  0.153834  ...  0.149414  0.161588  0.25049  0.191491
# 1 -0.092008 -0.081342 -0.180261  ... -0.214874 -0.199194 -0.05492 -0.037486
#
#          삼진       병살타       장타율       출루율        실책       OPS
# 0  0.243479  0.219536  0.184670  0.163153  0.156179  0.184548
# 1 -0.094340 -0.030098  0.412026  0.446924 -0.121904  0.446650
#
# [2 rows x 23 columns]

# %%
# 각 주성분의 고유벡터 가져오기
eigen_vectors = pca.components_

# 주성분의 고유벡터 출력
for i, eigenvector in enumerate(eigen_vectors):
    print(f"PC{i + 1} (Eigenvalue: {pca.explained_variance_ratio_[i]:.2f}) = {eigenvector}")
# Out:
# PC1 (Eigenvalue: 0.57) = [0.12712673 0.00349667 0.1977674  0.15112617 0.24450873 0.26551118
#  0.26309532 0.26669449 0.25710228 0.15383402 0.21999962 0.26909423
#  0.257241   0.14941424 0.16158765 0.25048996 0.19149127 0.24347855
#  0.21953563 0.18467045 0.1631532  0.15617874 0.18454755]
# PC2 (Eigenvalue: 0.11) = [ 0.04589752  0.09345249  0.01065205  0.46244944 -0.1116897  -0.11559246
#  -0.10759499 -0.09200821 -0.08134229 -0.18026139  0.03696844 -0.06427628
#  -0.02757646 -0.21487366 -0.19919361 -0.05491961 -0.03748639 -0.09434042
#  -0.03009835  0.4120256   0.4469241  -0.12190402  0.44665015]

# %%
# 각 차원별로 절댓값 크기 상위 5개와 그 인덱스 추출
abs_values = np.abs(eigen_vectors)  # 배열의 절댓값 계산

# 각 차원별로 상위 5개 인덱스 추출 (절댓값 크기 내림차순)
top_indices = np.argsort(-abs_values, axis=1)[:, :5]  # 각 행에서 상위 5개 인덱스 추출

# 결과 출력
lst_pca1 = list(top_indices[0])
lst_pca2 = list(top_indices[1])
lst1 = []
lst2 = []
for i in lst_pca1:
    lst1.append(scaled_df_1516.columns[i])
for i in lst_pca2:
    lst2.append(scaled_df_1516.columns[i])
print('pca1의 분산에 가장 큰 영향을 준 변수 상위 5개')
print(lst1)
print('pca2에의 분산에 가장 큰 영향을 준 변수 상위 5개')
print(lst2)
# Out:
# pca1의 분산에 가장 큰 영향을 준 변수 상위 5개
# ['루타', '안타', '타수', '득점', '타점']
# pca2에의 분산에 가장 큰 영향을 준 변수 상위 5개
# ['타율', '출루율', 'OPS', '장타율', '도루']

# %%
pca_df
# Out:
#           PC1       PC2
# 0    1.045770 -1.082503
# 1   -2.450792 -0.814569
# 2   -4.051592  0.392934
# 3   -5.533233 -3.167844
# 4   -5.575579 -3.362216
# ..        ...       ...
# 363 -4.800393 -2.109214
# 364  6.897651 -1.499819
# 365  7.347935 -0.922117
# 366 -5.519369 -3.341113
# 367 -5.323023 -3.252789
#
# [368 rows x 2 columns]

# %%
# # 적절한 군집수 찾기
# Inertia(군집 내 거리제곱합의 합) value (적정 군집수)

ks = range(1,10)
inertias = []

for k in ks:
    model = KMeans(n_clusters=k)
    model.fit(pca_df)
    inertias.append(model.inertia_)

# Plot ks vs inertias
plt.figure(figsize=(4, 4))

plt.plot(ks, inertias, '-o')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(ks)
plt.show()

# %%
# 군집개수에 따른 실루엣 계수 분포 확인 함수
def visualize_silhouette(cluster_lists, X_features): 

    from sklearn.datasets import make_blobs
    from sklearn.cluster import KMeans
    from sklearn.metrics import silhouette_samples, silhouette_score

    import matplotlib.pyplot as plt
    import matplotlib.cm as cm
    import math

    # 입력값으로 클러스터링 갯수들을 리스트로 받아서, 각 갯수별로 클러스터링을 적용하고 실루엣 개수를 구함
    n_cols = len(cluster_lists)

    # plt.subplots()으로 리스트에 기재된 클러스터링 수만큼의 sub figures를 가지는 axs 생성 
    fig, axs = plt.subplots(figsize=(4*n_cols, 4), nrows=1, ncols=n_cols)

    # 리스트에 기재된 클러스터링 갯수들을 차례로 iteration 수행하면서 실루엣 개수 시각화
    for ind, n_cluster in enumerate(cluster_lists):

        # KMeans 클러스터링 수행하고, 실루엣 스코어와 개별 데이터의 실루엣 값 계산. 
        clusterer = KMeans(n_clusters = n_cluster, max_iter=500, random_state=0)
        cluster_labels = clusterer.fit_predict(X_features)

        sil_avg = silhouette_score(X_features, cluster_labels)
        sil_values = silhouette_samples(X_features, cluster_labels)

        y_lower = 10
        axs[ind].set_title('Number of Cluster : '+ str(n_cluster)+'\n' \
                          'Silhouette Score :' + str(round(sil_avg,3)) )
        axs[ind].set_xlabel("The silhouette coefficient values")
        axs[ind].set_ylabel("Cluster label")
        axs[ind].set_xlim([-0.1, 1])
        axs[ind].set_ylim([0, len(X_features) + (n_cluster + 1) * 10])
        axs[ind].set_yticks([])  # Clear the yaxis labels / ticks
        axs[ind].set_xticks([0, 0.2, 0.4, 0.6, 0.8, 1])

        # 클러스터링 갯수별로 fill_betweenx( )형태의 막대 그래프 표현. 
        for i in range(n_cluster):
            ith_cluster_sil_values = sil_values[cluster_labels==i]
            ith_cluster_sil_values.sort()

            size_cluster_i = ith_cluster_sil_values.shape[0]
            y_upper = y_lower + size_cluster_i

            color = cm.nipy_spectral(float(i) / n_cluster)
            axs[ind].fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_sil_values, \
                                facecolor=color, edgecolor=color, alpha=0.7)
            axs[ind].text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
            y_lower = y_upper + 10

        axs[ind].axvline(x=sil_avg, color="red", linestyle="--")


visualize_silhouette([2,3,4,5,6], pca_df)

# %% [markdown]
# # K-Means Clustering

# %%
#kmeans
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(pca_df)
label = kmeans.labels_
label = pd.Series(label)
pca_df['label'] = label.values
pca_df
# Out:
#           PC1       PC2  label
# 0    1.045770 -1.082503      1
# 1   -2.450792 -0.814569      0
# 2   -4.051592  0.392934      0
# 3   -5.533233 -3.167844      0
# 4   -5.575579 -3.362216      0
# ..        ...       ...    ...
# 363 -4.800393 -2.109214      0
# 364  6.897651 -1.499819      2
# 365  7.347935 -0.922117      2
# 366 -5.519369 -3.341113      0
# 367 -5.323023 -3.252789      0
#
# [368 rows x 3 columns]

# %%
pca_df['label'].value_counts()
# Out:
# 0    132
# 1    129
# 2    107
# Name: label, dtype: int64

# %%
# 시각화
import seaborn as sns

sns.scatterplot(data = pca_df, x = 'PC1',y = 'PC2', hue = 'label');

# %% [markdown]
# #### Visualization

# %%
df_cluster = df_1516.copy()
df_cluster['label'] = label.values
df_cluster_num = df_cluster.drop('팀명', axis=1)
df_cluster_num.drop('연도', axis=1, inplace=True)
df_cluster_num
# Out:
#        이름  연차    몸값(만원)     타율  경기수   타수  득점   안타  2루타  3루타  ...  도루실패  볼넷  \
# 3     강경학   3    6500.0  0.257  120  311  50   80    7    4  ...     3  40
# 4     강경학   4    6200.0  0.158   46  101  16   16    3    2  ...     0   8
# 8     강구성   2    2700.0  0.200    4    5   0    1    1    0  ...     0   0
# 9     강구성   3    2700.0  0.000    2    3   0    0    0    0  ...     0   0
# 39    강민국   2    2700.0  0.000    1    2   0    0    0    0  ...     0   0
# ...   ...  ..       ...    ...  ...  ...  ..  ...  ...  ...  ...   ...  ..
# 2431  황윤호   2    3000.0  0.083   33   12   7    1    0    0  ...     0   0
# 2442  황재균   9   50000.0  0.290  144  534  95  155   41    2  ...    10  48
# 2443  황재균  10  120000.0  0.335  127  498  97  167   26    5  ...    10  49
# 2450  황진수   4    2800.0  0.000    2    2   0    0    0    0  ...     0   0
# 2451  황진수   5    2800.0  0.000   11   10   2    0    0    0  ...     1   0
#
#       데드볼   삼진  병살타    장타율    출루율  실책    OPS  label
# 3       5   58    3  0.325  0.348  15  0.673      1
# 4       2   30    5  0.257  0.232   7  0.489      0
# 8       0    0    0  0.400  0.200   0  0.600      0
# 9       0    1    0  0.000  0.000   0  0.000      0
# 39      0    1    0  0.000  0.000   0  0.000      0
# ...   ...  ...  ...    ...    ...  ..    ...    ...
# 2431    0    5    0  0.083  0.083   0  0.166      0
# 2442    4  122   14  0.521  0.350  16  0.871      2
# 2443    4   66   10  0.570  0.394  15  0.964      2
# 2450    0    0    0  0.000  0.000   0  0.000      0
# 2451    0    5    0  0.000  0.000   0  0.000      0
#
# [368 rows x 24 columns]

# %% [markdown]
# - pca 진행전 원본 데이터셋에 클러스터링 결과를 맵핑해주어 결과 해석에 사용함

# %% [markdown]
# ##### 군집에 따른 변수별 평균, 분산

# %%
df_cluster.groupby('label').agg(['mean', 'var'])
# Out:
# /var/folders/gr/lhv5nx4d4ybdzwl7z8w22qym0000gn/T/ipykernel_29633/3914398195.py:1: FutureWarning: ['이름', '팀명'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_cluster.groupby('label').agg(['mean', 'var'])
#              연차                      연도                  몸값(만원)                \
#            mean        var         mean       var          mean           var
# label
# 0      4.159091  11.524115  2015.469697  0.250983   5003.787879  2.343594e+07
# 1      6.899225  19.388203  2015.558140  0.248547  12524.806202  1.367770e+08
# 2      9.205607  16.221478  2015.532710  0.251278  46981.308411  1.250274e+09
#
#              타율                   경기수               ...        병살타             \
#            mean       var        mean          var  ...       mean        var
# label                                               ...
# 0      0.175576  0.009226   31.454545   734.723109  ...   0.878788   1.695119
# 1      0.287698  0.010305   82.372093  1119.391715  ...   4.356589  10.574976
# 2      0.308626  0.000663  127.859813   173.121672  ...  10.672897  17.844825
#
#             장타율                 출루율                  실책                  OPS  \
#            mean       var      mean       var      mean        var      mean
# label
# 0      0.220113  0.014471  0.236830  0.011737  1.121212   2.687486  0.456943
# 1      0.422831  0.019576  0.359062  0.008775  3.705426  14.271923  0.781893
# 2      0.480727  0.006317  0.387124  0.001128  7.383178  33.710280  0.867851
#
#
#             var
# label
# 0      0.047038
# 1      0.044477
# 2      0.010882
#
# [3 rows x 46 columns]

# %% [markdown]
# ##### 군집에 따른 변수별 데이터 분포를 나타내는 그래프

# %%
df_cluster_num.drop('이름', axis=1, inplace=True)
df_cluster_0 = df_cluster_num[df_cluster_num['label'] == 0]
df_cluster_1 = df_cluster_num[df_cluster_num['label'] == 1]
df_cluster_2 = df_cluster_num[df_cluster_num['label'] == 2]

# %%
for col in df_cluster_num.columns:
    # 그래프 사이즈 조절
    plt.figure(figsize=(10, 6))

    # 첫 번째 서브플롯
    plt.subplot(3, 1, 1)
    plt.xlim()
    plt.ylabel('cluster 0')
    sns.histplot(data=df_cluster_0, x=col, kde=True)  # 히스토그램과 KDE 플롯

    # 두 번째 서브플롯
    plt.subplot(3, 1, 2)
    plt.ylabel('cluster 1')
    sns.histplot(data=df_cluster_1, x=col, kde=True)

    # 세 번째 서브플롯
    plt.subplot(3, 1, 3)
    plt.ylabel('cluster 2')
    sns.histplot(data=df_cluster_2, x=col, kde=True)

plt.tight_layout()  # 서브플롯들 간의 간격 조정
plt.show()
# Out:
# /var/folders/gr/lhv5nx4d4ybdzwl7z8w22qym0000gn/T/ipykernel_29633/2107111858.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(10, 6))
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47800 (\N{HANGUL SYLLABLE MOM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46301 (\N{HANGUL SYLLABLE DEUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51216 (\N{HANGUL SYLLABLE JEOM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50504 (\N{HANGUL SYLLABLE AN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54856 (\N{HANGUL SYLLABLE HOM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47088 (\N{HANGUL SYLLABLE REON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54056 (\N{HANGUL SYLLABLE PAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48380 (\N{HANGUL SYLLABLE BOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45367 (\N{HANGUL SYLLABLE NES}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45936 (\N{HANGUL SYLLABLE DE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49340 (\N{HANGUL SYLLABLE SAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48337 (\N{HANGUL SYLLABLE BYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49332 (\N{HANGUL SYLLABLE SAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52293 (\N{HANGUL SYLLABLE CAEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
